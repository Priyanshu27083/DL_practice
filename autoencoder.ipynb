# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu27083/DL_practice/blob/main/autoencoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
# 1. Load and Prepare Data
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) #Original shape: 60000 × 28 × 28 After reshape:60000 × 78
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))) #reshape is required for Dense layer expects 1D input vector

# 2. Define the Encoder and Decoder
input_dim = 784  # 28x28 images
encoding_dim = 2  # 32 features - Compressed representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)

# Decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# 3. Create the Autoencoder Model
autoencoder = Model(input_layer, decoded)

# 4. Compile the Model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 5. Train the Model
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
#Because autoencoder tries to learn: Input = Output


# 6. Test the Model
decoded_imgs = autoencoder.predict(x_test) #Input:test images Output:reconstructed images

# 7. Visualize Results
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.5823 - val_loss: 0.4930
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.4402 - val_loss: 0.3985
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.3711 - val_loss: 0.3492
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3338 - val_loss: 0.3212
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.3120 - val_loss: 0.3043
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2983 - val_loss: 0.2933
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2894 - val_loss: 0.2859
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.2832 - val_loss: 0.2807
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2788 - val_loss: 0.2769
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2755 - val_loss: 0.2740
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2731 - val_loss: 0.2719
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2712 - val_loss: 0.2702
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2697 - val_loss: 0.2689
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2685 - val_loss: 0.2678
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2676 - val_loss: 0.2670
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2668 - val_loss: 0.2663
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2662 - val_loss: 0.2657
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2657 - val_loss: 0.2652
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2653 - val_loss: 0.2648
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2649 - val_loss: 0.2645
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2646 - val_loss: 0.2642
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2644 - val_loss: 0.2640
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2641 - val_loss: 0.2638
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2640 - val_loss: 0.2636
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2638 - val_loss: 0.2635
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2637 - val_loss: 0.2633
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2636 - val_loss: 0.2632
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2635 - val_loss: 0.2631
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2634 - val_loss: 0.2631
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2633 - val_loss: 0.2630
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.2632 - val_loss: 0.2629
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2632 - val_loss: 0.2629
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2631 - val_loss: 0.2628
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2631 - val_loss: 0.2628
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2630 - val_loss: 0.2628
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.2630 - val_loss: 0.2627
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2629 - val_loss: 0.2626
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2628 - val_loss: 0.2625
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2628 - val_loss: 0.2625
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
# 1. Load and Prepare Data
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) #Original shape: 60000 × 28 × 28 After reshape:60000 × 78
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))) #reshape is required for Dense layer expects 1D input vector

# 2. Define the Encoder and Decoder
input_dim = 784  # 28x28 images
encoding_dim = 38  # 38 features - Compressed representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)

# Decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# 3. Create the Autoencoder Model
autoencoder = Model(input_layer, decoded)

# 4. Compile the Model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 5. Train the Model
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
#Because autoencoder tries to learn: Input = Output


# 6. Test the Model
decoded_imgs = autoencoder.predict(x_test) #Input:test images Output:reconstructed images

# 7. Visualize Results
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.3282 - val_loss: 0.2691
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2665 - val_loss: 0.2647
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2643 - val_loss: 0.2637
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2637 - val_loss: 0.2632
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.2629 - val_loss: 0.2607
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2588 - val_loss: 0.2566
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2556 - val_loss: 0.2539
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2518 - val_loss: 0.2486
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2452 - val_loss: 0.2407
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.2373 - val_loss: 0.2327
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2289 - val_loss: 0.2233
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.2194 - val_loss: 0.2143
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.2108 - val_loss: 0.2062
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 0.2035 - val_loss: 0.1993
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1970 - val_loss: 0.1932
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1916 - val_loss: 0.1884
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1872 - val_loss: 0.1842
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.1831 - val_loss: 0.1803
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1795 - val_loss: 0.1769
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1764 - val_loss: 0.1742
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1739 - val_loss: 0.1718
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1717 - val_loss: 0.1697
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1698 - val_loss: 0.1680
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1682 - val_loss: 0.1664
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1666 - val_loss: 0.1647
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1648 - val_loss: 0.1627
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1628 - val_loss: 0.1607
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1609 - val_loss: 0.1586
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1588 - val_loss: 0.1566
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1570 - val_loss: 0.1550
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1555 - val_loss: 0.1536
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1542 - val_loss: 0.1524
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1530 - val_loss: 0.1511
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1515 - val_loss: 0.1493
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1495 - val_loss: 0.1472
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1476 - val_loss: 0.1455
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.1460 - val_loss: 0.1439
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1443 - val_loss: 0.1421
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.1425 - val_loss: 0.1403
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1407 - val_loss: 0.1382
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1382 - val_loss: 0.1354
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1352 - val_loss: 0.1322
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1321 - val_loss: 0.1294
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1294 - val_loss: 0.1265
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1263 - val_loss: 0.1233
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1229 - val_loss: 0.1198
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.1195 - val_loss: 0.1167
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1167 - val_loss: 0.1141
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.1141 - val_loss: 0.1117
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.1118 - val_loss: 0.1095
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
# 1. Load and Prepare Data
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) #Original shape: 60000 × 28 × 28 After reshape:60000 × 78
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))) #reshape is required for Dense layer expects 1D input vector

# 2. Define the Encoder and Decoder
input_dim = 1000  # 28x28 images
encoding_dim = 70  # 70 features - Compressed representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)

# Decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# 3. Create the Autoencoder Model
autoencoder = Model(input_layer, decoded)

# 4. Compile the Model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 5. Train the Model
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
#Because autoencoder tries to learn: Input = Output


# 6. Test the Model
decoded_imgs = autoencoder.predict(x_test) #Input:test images Output:reconstructed images

# 7. Visualize Results
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - loss: 0.3039 - val_loss: 0.2651
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.2627 - val_loss: 0.2581
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.2502 - val_loss: 0.2390
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.2273 - val_loss: 0.2153
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.2070 - val_loss: 0.1981
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1925 - val_loss: 0.1856
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1814 - val_loss: 0.1754
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1719 - val_loss: 0.1668
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1641 - val_loss: 0.1597
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1577 - val_loss: 0.1540
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1524 - val_loss: 0.1489
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1477 - val_loss: 0.1445
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1434 - val_loss: 0.1404
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1396 - val_loss: 0.1367
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1361 - val_loss: 0.1334
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1330 - val_loss: 0.1304
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1302 - val_loss: 0.1278
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 0.1277 - val_loss: 0.1255
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.1256 - val_loss: 0.1234
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1237 - val_loss: 0.1216
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1220 - val_loss: 0.1200
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 0.1205 - val_loss: 0.1186
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1192 - val_loss: 0.1174
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1180 - val_loss: 0.1163
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1169 - val_loss: 0.1152
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1160 - val_loss: 0.1143
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 0.1151 - val_loss: 0.1134
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1143 - val_loss: 0.1126
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1135 - val_loss: 0.1120
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1128 - val_loss: 0.1113
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.1122 - val_loss: 0.1105
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1111 - val_loss: 0.1091
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1092 - val_loss: 0.1067
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1062 - val_loss: 0.1034
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.1030 - val_loss: 0.1004
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1000 - val_loss: 0.0976
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0973 - val_loss: 0.0950
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0948 - val_loss: 0.0927
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0926 - val_loss: 0.0907
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 0.0906 - val_loss: 0.0889
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0889 - val_loss: 0.0873
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0873 - val_loss: 0.0858
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0859 - val_loss: 0.0846
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0847 - val_loss: 0.0834
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0836 - val_loss: 0.0825
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0827 - val_loss: 0.0816
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0819 - val_loss: 0.0808
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0811 - val_loss: 0.0802
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0805 - val_loss: 0.0796
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.0799 - val_loss: 0.0791
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
# 1. Load and Prepare Data
(x_train, _), (x_test, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))) #Original shape: 60000 × 28 × 28 After reshape:60000 × 78
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))) #reshape is required for Dense layer expects 1D input vector

# 2. Define the Encoder and Decoder
input_dim = 784  # 28x28 images
encoding_dim = 1000  # 32 features - Compressed representation

# Encoder
input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='sigmoid')(input_layer)

# Decoder
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# 3. Create the Autoencoder Model
autoencoder = Model(input_layer, decoded)

# Create separate encoder model
encoder = Model(input_layer, encoded)

# 4. Compile the Model
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# 5. Train the Model
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))
#Because autoencoder tries to learn: Input = Output


# 6. Test the Model
decoded_imgs = autoencoder.predict(x_test) #Input:test images Output:reconstructed images

# Get encoded representations (1000 neurons)
encoded_imgs = encoder.predict(x_test)

# Print first image's encoded values
print(encoded_imgs[0])

# 7. Visualize Results
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # Display original image
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstructed image
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

import matplotlib.pyplot as plt

plt.plot(encoded_imgs[0])
plt.title("Encoded Representation (1000 neurons)")
plt.show()
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - loss: 0.1783 - val_loss: 0.1178
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.1021 - val_loss: 0.0893
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step - loss: 0.0846 - val_loss: 0.0791
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.0773 - val_loss: 0.0743
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - loss: 0.0734 - val_loss: 0.0715
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 21s 57ms/step - loss: 0.0711 - val_loss: 0.0697
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 20s 55ms/step - loss: 0.0695 - val_loss: 0.0685
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - loss: 0.0684 - val_loss: 0.0676
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 57ms/step - loss: 0.0676 - val_loss: 0.0670
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - loss: 0.0670 - val_loss: 0.0665
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 20s 54ms/step - loss: 0.0665 - val_loss: 0.0661
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 54ms/step - loss: 0.0661 - val_loss: 0.0658
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 13s 55ms/step