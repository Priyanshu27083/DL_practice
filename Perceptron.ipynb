# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu27083/DL_practice/blob/main/Perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
def sigmoid(x):
  return 1/(1+np.exp(-x))

class Neuron:
  def __init__(self, weights, bias):
    self.weights = weights
    self.bias = bias

  def feedforward(self, inputs):
    total = np.dot(self.weights, inputs) + self.bias
    return 1 if sigmoid(total) >= 0.5 else 0

weights = [1,1]
inputs = [[0,0],[0,1],[1,0],[1,1]]
bias = -1.5
for n in inputs:
  ins = Neuron(weights,bias)
  x = ins.feedforward(n)
  print(x)
# Out:
# 0
# 0
# 0
# 1

# %%
#AND gate perceptron with activation function

import numpy as np

class Neuron:
  def __init__(self, weights, bias):
    self.weights = weights
    self.bias = bias

  def feedforward(self, inputs):
    total = np.dot(self.weights, inputs) + self.bias #Activation function
    return 1 if total > 0 else 0

weights = [1,1]
inputs = [[0,0],[0,1],[1,0],[1,1]]
bias = -1.5
for n in inputs:
  ins = Neuron(weights,bias)
  x = ins.feedforward(n)
  print(x)
# Out:
# 0
# 0
# 0
# 1

# %%
#OR gate perceptron with activation function
import numpy as np
class Neuron:
  def __init__(self, weights, bias):
    self.weights = weights
    self.bias = bias

  def feedforward(self, inputs):
    total = np.dot(self.weights, inputs) + self.bias #Activation function
    return 1 if total > 0 else 0 #Step function

weights = [1,1]
inputs = [[0,0],[0,1],[1,0],[1,1]]
bias = -0.5
for n in inputs:
  ins = Neuron(weights,bias)
  x = ins.feedforward(n)
  print(x)
# Out:
# 0
# 1
# 1
# 1

# %%
def NAND(x1,x2):
  w1 = -1
  w2 = -1
  bias = 1.5
  activation = w1*x1 + w2*x2 + bias
  if activation >= 0:
    return 1
  else:
    return 0

inputs = [[0,0],[0,1],[1,0],[1,1]]
print("NAND",end = " ")
for n in inputs:
  print(NAND(n[0],n[1]),end = " ")

def OR(x1,x2):
  w1 = 1
  w2 = 1
  bias = -0.5
  activation = w1*x1 + w2*x2 + bias
  if activation >= 0:
    return 1
  else:
    return 0

inputs = [[0,0],[0,1],[1,0],[1,1]]
print()
print("OR",end = " ")
for n in inputs:
  print(OR(n[0],n[1]),end = " ")

def AND(x1,x2):
  w1 = 1
  w2 = 1
  bias = -1.5
  activation = w1*x1 + w2*x2 + bias
  if activation >= 0:
    return 1
  else:
    return 0

inputs = [[0,0],[0,1],[1,0],[1,1]]
print()
print("AND",end = " ")
for n in inputs:
  print(AND(n[0],n[1]),end = " ")

def NOR(x1,x2):
  w1 = -1
  w2 = -1
  bias = 0.5
  activation = w1*x1 + w2*x2 + bias
  if activation >= 0:
    return 1
  else:
    return 0

inputs = [[0,0],[0,1],[1,0],[1,1]]
print()
print("NOR",end = " ")
for n in inputs:
  print(OR(n[0],n[1]),end = " ")

#Uses multilayer perceptron
def XOR(x1,x2):
  h1 = OR(x1,x2)
  h2 = NAND(x1,x2)
  return AND(h1,h2)

inputs = [[0,0],[0,1],[1,0],[1,1]]
print()
print("XOR",end = " ")
for n in inputs:
  print(XOR(n[0],n[1]),end = " ")

def XNOR(x1,x2):
  h1 = NOR(x1,x2)
  h2 = AND(x1,x2)
  return OR(h1,h2)

inputs = [[0,0],[0,1],[1,0],[1,1]]
print()
print("XNOR",end = " ")
for n in inputs:
  print(XNOR(n[0],n[1]),end = " ")
# Out:
# NAND 1 1 1 0
# OR 0 1 1 1
# AND 0 0 0 1
# NOR 0 1 1 1
# XOR 0 1 1 0
# XNOR 1 0 0 1

# %%
def NAND(input):
  weights = [-1,-1]
  bias = 1.5
  activation = np.dot(weights,input) + bias
  if activation >= 0:
    return 1
  else:
    return 0

inputs = [[0,0],[0,1],[1,0],[1,1]]
print("NAND",end = " ")
for n in inputs:
  print(NAND(n),end = " ")
# Out:
# NAND 1 1 1 0

# %%
import numpy as np
# Step (threshold) activation function
def step(x):
    if x >= 0:
        return 1
    else:
        return 0

class Perceptron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias

    def predict(self, inputs):
        net = np.dot(self.weights, inputs) + self.bias
        return step(net), net

# AND gate perceptron
weights = np.array([1, 1])
bias = -1.5

p = Perceptron(weights, bias)

# Inputs very close to decision boundary
test_inputs = [
    [0.74, 0.74],  # just below threshold
    [0.75, 0.75],  # exactly at threshold
    [0.76, 0.76]   # just above threshold
]

print("x1    x2    net_input   output")
for x in test_inputs:
    y, net = p.predict(x)
    print(f"{x[0]:.2f}  {x[1]:.2f}   {net:+.4f}      {y}")
# Out:
# x1    x2    net_input   output
# 0.74  0.74   -0.0200      0
# 0.75  0.75   +0.0000      1
# 0.76  0.76   +0.0200      1

# %%
import numpy as np
import pandas as pd

def step(x):
    return 1 if x >= 0 else 0

class Perceptron:
    def __init__(self, lr=0.1, epochs=10):
        self.lr = lr
        self.epochs = epochs

    def fit(self, X, y):
        self.weights = np.zeros(X.shape[1])
        self.bias = 0

        for epoch in range(self.epochs):
            errors = 0
            print(f"\nEpoch {epoch+1}")
            for i in range(len(X)):
                net = np.dot(X[i], self.weights) + self.bias
                y_pred = step(net)
                error = y[i] - y_pred

                if error != 0:
                    self.weights += self.lr * error * X[i]
                    self.bias += self.lr * error
                    errors += 1

                print(f"Weights: {self.weights}, Bias: {self.bias}")

            print(f"Misclassifications: {errors}")

    def predict(self, X):
        return [step(np.dot(x, self.weights) + self.bias) for x in X]


X = np.array([
    [1, 1, 0, 0.85],
    [0, 1, 1, 0.90],
    [1, 0, 0, 0.60],
    [0, 0, 1, 0.95],
    [0, 1, 0, 0.40],
    [1, 0, 1, 0.50],
    [0, 0, 0, 0.30],
    [0, 1, 1, 0.45],
])

y = np.array([1, 1, 1, 1, 0, 0, 0, 0])

p = Perceptron(lr=0.1, epochs=9)
p.fit(X, y)

preds = p.predict(X)
print("\nPredictions:", preds)
print("Actual:     ", y.tolist())
# Out:
# Epoch 1
# Weights: [0. 0. 0. 0.], Bias: 0
# Weights: [0. 0. 0. 0.], Bias: 0
# Weights: [0. 0. 0. 0.], Bias: 0
# Weights: [0. 0. 0. 0.], Bias: 0
# Weights: [ 0.   -0.1   0.   -0.04], Bias: -0.1
# Weights: [ 0.   -0.1   0.   -0.04], Bias: -0.1
# Weights: [ 0.   -0.1   0.   -0.04], Bias: -0.1
# Weights: [ 0.   -0.1   0.   -0.04], Bias: -0.1
# Misclassifications: 1
#
# Epoch 2
# Weights: [0.1   0.    0.    0.045], Bias: 0.0
# Weights: [0.1   0.    0.    0.045], Bias: 0.0
# Weights: [0.1   0.    0.    0.045], Bias: 0.0
# Weights: [0.1   0.    0.    0.045], Bias: 0.0
# Weights: [ 0.1   -0.1    0.     0.005], Bias: -0.1
# Weights: [ 0.    -0.1   -0.1   -0.045], Bias: -0.2
# Weights: [ 0.    -0.1   -0.1   -0.045], Bias: -0.2
# Weights: [ 0.    -0.1   -0.1   -0.045], Bias: -0.2
# Misclassifications: 3
#
# Epoch 3
# Weights: [ 0.1   0.   -0.1   0.04], Bias: -0.1
# Weights: [0.1  0.1  0.   0.13], Bias: 0.0
# Weights: [0.1  0.1  0.   0.13], Bias: 0.0
# Weights: [0.1  0.1  0.   0.13], Bias: 0.0
# ...

# %%
import numpy as np
import pandas as pd
movie = pd.read_excel("/content/movie.csv.xlsx")

def step(x):
    return 1 if x >= 0 else 0
X = movie.iloc[:, :-1].values
y = movie.iloc[:, -1].values

#i
def mp_perceptron(x):
    return step(np.sum(x))

print("MP Perceptron Results:")
for i in range(len(X)):
    print(f"Actual: {y[i]}, Predicted: {mp_perceptron(X[i])}")
# Out:
# MP Perceptron Results:
# Actual: 1, Predicted: 1
# Actual: 1, Predicted: 1
# Actual: 1, Predicted: 1
# Actual: 0, Predicted: 1
# Actual: 0, Predicted: 1
# Actual: 0, Predicted: 1

# %%
lr = 0.1
epochs = 10

# initialize weights
w = np.zeros(X.shape[1])

print("\nPerceptron without Bias")

for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}")
    for i in range(len(X)):
        net = np.dot(X[i], w)
        y_pred = step(net)
        error = y[i] - y_pred

        if error != 0:
            w = w + lr * error * X[i]

        print("Weights:", w)
# Out:
# Perceptron without Bias
#
# Epoch 1
# Weights: [0. 0. 0. 0.]
# Weights: [0. 0. 0. 0.]
# Weights: [0. 0. 0. 0.]
# Weights: [ 0.    0.   -0.1  -0.04]
# Weights: [ 0.    0.   -0.1  -0.04]
# Weights: [ 0.    0.   -0.1  -0.04]
#
# Epoch 2
# Weights: [ 0.1    0.1   -0.1    0.045]
# Weights: [ 0.1    0.1   -0.1    0.045]
# Weights: [ 0.1    0.1   -0.1    0.045]
# Weights: [ 0.1    0.1   -0.1    0.045]
# Weights: [ 0.1    0.    -0.1    0.015]
# Weights: [ 0.     0.    -0.2   -0.035]
#
# Epoch 3
# Weights: [ 0.1   0.1  -0.2   0.05]
# Weights: [ 0.1   0.2  -0.1   0.14]
# Weights: [ 0.1   0.2  -0.1   0.14]
# Weights: [ 0.1   0.2  -0.1   0.14]
# Weights: [ 0.1   0.1  -0.1   0.11]
# Weights: [ 0.    0.1  -0.2   0.06]
#
# Epoch 4
# Weights: [ 0.    0.1  -0.2   0.06]
# Weights: [ 0.    0.2  -0.1   0.15]
# Weights: [ 0.    0.2  -0.1   0.15]
# Weights: [ 0.    0.2  -0.1   0.15]
# Weights: [ 0.    0.1  -0.1   0.12]
# Weights: [ 0.    0.1  -0.1   0.12]
#
# Epoch 5
# Weights: [ 0.    0.1  -0.1   0.12]
# ...

# %%
lr = 0.1
epochs = 10

w = np.zeros(X.shape[1])
b = 0

print("\nPerceptron with Weights and Bias")

for epoch in range(epochs):
    errors = 0
    print(f"\nEpoch {epoch+1}")
    for i in range(len(X)):
        net = np.dot(X[i], w) + b
        y_pred = step(net)
        error = y[i] - y_pred

        if error != 0:
            w = w + lr * error * X[i]
            b = b + lr * error
            errors += 1

        print("Weights:", w, "Bias:", b)

    print("Misclassifications:", errors)

    test_movie = np.array([1, 1, 0, 0.8])

print("\nTest Movie Prediction")

print("MP Perceptron:", step(np.sum(test_movie)))
print("Without Bias:", step(np.dot(test_movie, w)))
print("With Bias:", step(np.dot(test_movie, w) + b))
# Out:
# Perceptron with Weights and Bias
#
# Epoch 1
# Weights: [0. 0. 0. 0.] Bias: 0
# Weights: [0. 0. 0. 0.] Bias: 0
# Weights: [0. 0. 0. 0.] Bias: 0
# Weights: [ 0.    0.   -0.1  -0.04] Bias: -0.1
# Weights: [ 0.    0.   -0.1  -0.04] Bias: -0.1
# Weights: [ 0.    0.   -0.1  -0.04] Bias: -0.1
# Misclassifications: 1
#
# Epoch 2
# Weights: [ 0.1    0.1   -0.1    0.045] Bias: 0.0
# Weights: [ 0.1    0.1   -0.1    0.045] Bias: 0.0
# Weights: [ 0.1    0.1   -0.1    0.045] Bias: 0.0
# Weights: [ 0.1    0.1   -0.1    0.045] Bias: 0.0
# Weights: [ 0.1    0.    -0.1    0.015] Bias: -0.1
# Weights: [ 0.1    0.    -0.1    0.015] Bias: -0.1
# Misclassifications: 2
#
# Epoch 3
# Weights: [ 0.1    0.    -0.1    0.015] Bias: -0.1
# Weights: [0.1   0.1   0.    0.105] Bias: 0.0
# Weights: [0.1   0.1   0.    0.105] Bias: 0.0
# Weights: [ 0.1    0.1   -0.1    0.065] Bias: -0.1
# Weights: [ 0.1    0.    -0.1    0.035] Bias: -0.2
# Weights: [ 0.1    0.    -0.1    0.035] Bias: -0.2
# Misclassifications: 3
#
# ...

# %%
# Step activation function
def step(z):
    return 1 if z >= 0 else 0


# Hidden layer perceptrons
# Each tuple: (w1, w2, bias)
hidden_neurons = [
    (-1, -1,  0.5),   # detects (0,0)
    (-1,  1, -0.5),   # detects (0,1)
    ( 1, -1, -0.5),   # detects (1,0)
    ( 1,  1, -1.5)    # detects (1,1)
]


def hidden_layer(x1, x2):
    h = []
    for w1, w2, b in hidden_neurons:
        z = w1*x1 + w2*x2 + b
        h.append(step(z))
    return h


def mlp(x1, x2, output_weights, theta=0.5):
    h = hidden_layer(x1, x2)
    z = 0
    for w, hi in zip(output_weights, h):
        z += w * hi
    z -= theta
    return step(z)


# -------- Example: XOR --------
xor_weights = [0, 1, 1, 0]

print("XOR Truth Table")

inputs = [
    (0, 0),
    (0, 1),
    (1, 0),
    (1, 1)
]

for x1, x2 in inputs:
    y = mlp(x1, x2, xor_weights)
    print("x1 =", x1, ", x2 =", x2, "-> y =", y)
# Out:
# XOR Truth Table
# x1 = 0 , x2 = 0 -> y = 0
# x1 = 0 , x2 = 1 -> y = 1
# x1 = 1 , x2 = 0 -> y = 1
# x1 = 1 , x2 = 1 -> y = 0

# %%
#10
import numpy as np
import matplotlib.pyplot as plt

# -------------------------------
# Sigmoid activation
# -------------------------------
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return x * (1 - x)

# -------------------------------
# XOR dataset
# -------------------------------
X = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

y = np.array([[0], [1], [1], [0]])

# -------------------------------
# Initialize weights and bias
# -------------------------------
np.random.seed(42)
W1 = np.random.rand(2, 2)
b1 = np.random.rand(1, 2)
W2 = np.random.rand(2, 1)
b2 = np.random.rand(1, 1)

learning_rate = 0.1
epochs = 10000
losses = []

# -------------------------------
# Gradient Descent Training
# -------------------------------
for epoch in range(epochs):

    # Forward pass
    h_input = np.dot(X, W1) + b1
    h_output = sigmoid(h_input)

    o_input = np.dot(h_output, W2) + b2
    y_pred = sigmoid(o_input)

    # Loss (MSE)
    error = y - y_pred
    loss = np.mean(error ** 2)
    losses.append(loss)

    # Backpropagation
    d_output = error * sigmoid_derivative(y_pred)
    d_hidden = d_output.dot(W2.T) * sigmoid_derivative(h_output)

    # Gradient Descent update
    W2 += h_output.T.dot(d_output) * learning_rate
    b2 += np.sum(d_output, axis=0, keepdims=True) * learning_rate

    W1 += X.T.dot(d_hidden) * learning_rate
    b1 += np.sum(d_hidden, axis=0, keepdims=True) * learning_rate

# -------------------------------
# Plot convergence curve
# -------------------------------
plt.plot(losses)
plt.xlabel("Epochs")
plt.ylabel("Loss (MSE)")
plt.title("Convergence of MLP using Gradient Descent")
plt.show()

# %%
#11
from sklearn.datasets import load_iris
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Binary classification (Setosa vs Others)
y = (y == 0).astype(int)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Feature scaling (important for Perceptron)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

learning_rates = [0.0001, 0.001, 0.01, 0.1, 1.0]

print("Learning Rate vs Accuracy")
print("-" * 30)

for lr in learning_rates:
    model = Perceptron(
        eta0=lr,
        max_iter=10,
        tol=1e-3,
        random_state=42
    )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    print(f"eta0 = {lr:<6} → Accuracy = {acc:.4f}")
# Out:
# Learning Rate vs Accuracy
# ------------------------------
# eta0 = 0.0001 → Accuracy = 1.0000
# eta0 = 0.001  → Accuracy = 1.0000
# eta0 = 0.01   → Accuracy = 1.0000
# eta0 = 0.1    → Accuracy = 1.0000
# eta0 = 1.0    → Accuracy = 1.0000

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Feature scaling (very important for MLP)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
learning_rates = [0.0001, 0.001, 0.01, 0.1]

print("Learning Rate vs Accuracy")
print("-" * 35)

for lr in learning_rates:
    mlp = MLPClassifier(
        hidden_layer_sizes=(10,),
        learning_rate_init=lr,
        max_iter=500,
        random_state=42
    )
    mlp.fit(X_train, y_train)
    y_pred = mlp.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"Learning Rate = {lr:<7} → Accuracy = {acc:.4f}")
iterations = [100, 300, 500, 1000]

print("\nIterations vs Accuracy")
print("-" * 35)

for it in iterations:
    mlp = MLPClassifier(
        hidden_layer_sizes=(10,),
        learning_rate_init=0.01,
        max_iter=it,
        random_state=42
    )
    mlp.fit(X_train, y_train)
    y_pred = mlp.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"Iterations = {it:<5} → Accuracy = {acc:.4f}")
# Out:
# Learning Rate vs Accuracy
# -----------------------------------
# Learning Rate = 0.0001  → Accuracy = 0.3111
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Learning Rate = 0.001   → Accuracy = 0.9778
# Learning Rate = 0.01    → Accuracy = 1.0000
# Learning Rate = 0.1     → Accuracy = 1.0000
#
# Iterations vs Accuracy
# -----------------------------------
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
# ...

# %%
#13
# Using SGD Optimizer
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import altair as alt
from tensorflow.keras.optimizers import SGD

# expected values
y = np.array([[0, 1, 1, 0]]).T

# features
X = np.array([[0, 0, 1, 1],
              [0, 1, 0, 1]]).T

model_sgd = Sequential()
model_sgd.add(Dense(16, input_dim=2, activation='sigmoid'))
model_sgd.add(Dense(1, activation='sigmoid'))

model_sgd.compile(loss='mean_squared_error',
                  optimizer=SGD(),
                  metrics=['binary_accuracy', 'mean_squared_error'])

history_sgd = model_sgd.fit(X, y, epochs=1000, verbose=0)

errors_sgd = history_sgd.history['loss']

df_sgd = pd.DataFrame({"errors": errors_sgd, "time-step": np.arange(0, len(errors_sgd))})

# Visualization with Altair for SGD optimizer
alt.Chart(df_sgd).mark_line().encode(x="time-step", y="errors").properties(title='SGD Optimizer - Loss Curve')

# Predictions and Accuracy
y_pred_sgd = model_sgd.predict(X).round()
num_correct_predictions_sgd = (y_pred_sgd == y).sum()
accuracy_sgd = (num_correct_predictions_sgd / y.shape[0]) * 100
print('SGD Optimizer accuracy: %.2f%%' % accuracy_sgd)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# SGD Optimizer accuracy: 50.00%

# %%
# Using MGD (Momentum Gradient Descent) Optimizer
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import altair as alt
from tensorflow.keras.optimizers import SGD
# expected values
y = np.array([[0, 1, 1, 0]]).T

# features
X = np.array([[0, 0, 1, 1],
              [0, 1, 0, 1]]).T
model_mgd = Sequential()
model_mgd.add(Dense(16, input_dim=2, activation='sigmoid'))
model_mgd.add(Dense(1, activation='sigmoid'))

# Using Momentum in SGD
model_mgd.compile(loss='mean_squared_error',
                  optimizer=SGD(momentum=0.1),
                  metrics=['binary_accuracy', 'mean_squared_error'])
#momentum= 0.9 This parameter indicates how much of the previous update to consider when updating the current weight.
#momentum=0.9 would mean that 90% of the previous weight update is added to the current update, which can help the model converge more quickly.

history_mgd = model_mgd.fit(X, y, epochs=1000, verbose=0)

errors_mgd = history_mgd.history['loss']

df_mgd = pd.DataFrame({"errors": errors_mgd, "time-step": np.arange(0, len(errors_mgd))})

# Visualization with Altair for MGD optimizer
alt.Chart(df_mgd).mark_line().encode(x="time-step", y="errors").properties(title='MGD Optimizer - Loss Curve')

# Predictions and Accuracy
y_pred_mgd = model_mgd.predict(X).round()
num_correct_predictions_mgd = (y_pred_mgd == y).sum()
accuracy_mgd = (num_correct_predictions_mgd / y.shape[0]) * 100
print('MGD Optimizer accuracy: %.2f%%' % accuracy_mgd)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# MGD Optimizer accuracy: 50.00%

# %%
# Install necessary libraries
# !pip install tensorflow matplotlib

# Step 3: Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Step 4: Load and Prepare the Data
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train / 255.0
x_test = x_test / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Step 5: Build the Model
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Step 6: Compile the Model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Step 7: Train the Model
history = model.fit(x_train, y_train, epochs=10, validation_split=0.2)

# Step 8: Evaluate the Model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')

# Step 9: Data Visualization
# Plot the training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label = 'Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label = 'Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.title('Model Loss')

plt.show()

# Visualize some predictions
predictions = model.predict(x_test)

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.xlabel(f"True: {np.argmax(y_test[i])}, Pred: {np.argmax(predictions[i])}")
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8587 - loss: 0.4693 - val_accuracy: 0.9539 - val_loss: 0.1463
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9661 - loss: 0.1147 - val_accuracy: 0.9676 - val_loss: 0.1029
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9768 - loss: 0.0754 - val_accuracy: 0.9691 - val_loss: 0.0972
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9815 - loss: 0.0586 - val_accuracy: 0.9707 - val_loss: 0.0969
# Epoch 5/10
# ...

# %% [markdown]
# **Regularization**

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models, regularizers

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the input data
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# 🔹 FIX: Reshape 28x28 images into 784-length vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define a simple model with L2 regularization
def build_l2_model():
    model = models.Sequential([
        layers.Dense(64, activation='relu',
                     input_shape=(784,),
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(0.01)),
        layers.Dense(10, activation='softmax')
    ])
    return model

model_l2 = build_l2_model()

model_l2.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
history = model_l2.fit(
    x_train,
    y_train,
    epochs=10,
    validation_split=0.2,
    batch_size=32
)

# Evaluate the model
test_loss, test_acc = model_l2.evaluate(x_test, y_test)

print(f"Test accuracy: {test_acc:.4f}")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8864 - loss: 0.8242 - val_accuracy: 0.9223 - val_loss: 0.5405
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9202 - loss: 0.5216 - val_accuracy: 0.9281 - val_loss: 0.4887
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9283 - loss: 0.4641 - val_accuracy: 0.9384 - val_loss: 0.4237
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9357 - loss: 0.4250 - val_accuracy: 0.9356 - val_loss: 0.4184
# Epoch 5/10
# ...

# %%
#week1
#neural network using pytorch
import torch
import torch.nn as nn
import torch.optim as optim
# Sample dataset
X = torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y = torch.tensor([[0.],[1.],[1.],[0.]])

# Neural Network Model
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.layer1 = nn.Linear(2,4)
        self.layer2 = nn.Linear(4,1)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.sigmoid(self.layer2(x))
        return x

model = SimpleNN()

loss_fn = nn.BCELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Training
for epoch in range(1000):
    output = model(X)
    loss = loss_fn(output, y)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

print(model(X))
# Out:
# tensor([[0.0138],
#         [0.9885],
#         [0.9885],
#         [0.0162]], grad_fn=<SigmoidBackward0>)

# %%
import numpy as np
from sklearn.linear_model import Perceptron
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0
)

# Different learning rates
learning_rates = [0.0001, 0.001, 0.01, 0.1, 1]

for lr in learning_rates:

    model = Perceptron(
        eta0=lr,           # learning rate
        max_iter=1000,     # number of epochs
        tol=1e-3,          # stopping condition
        random_state=0
    )

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)

    print(f"Learning Rate: {lr}, Accuracy: {acc:.3f}")
# Out:
# Learning Rate: 0.0001, Accuracy: 0.644
# Learning Rate: 0.001, Accuracy: 0.622
# Learning Rate: 0.01, Accuracy: 0.800
# Learning Rate: 0.1, Accuracy: 0.800
# Learning Rate: 1, Accuracy: 0.800

# %%
#MLPClassifier
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0
)

learning_rates = [0.001, 0.01, 0.1]
iterations = [200, 500, 1000]

for lr in learning_rates:
    for it in iterations:

        model = MLPClassifier(
            hidden_layer_sizes=(10,),   # one hidden layer with 10 neurons
            learning_rate_init=lr,
            max_iter=it,
            random_state=0
        )

        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)

        acc = accuracy_score(y_test, y_pred)

        print(f"Learning Rate: {lr}, Iterations: {it}, Accuracy: {acc:.3f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Learning Rate: 0.001, Iterations: 200, Accuracy: 0.644
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Learning Rate: 0.001, Iterations: 500, Accuracy: 0.933
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Learning Rate: 0.001, Iterations: 1000, Accuracy: 0.978
# ...

# %%
#gradient descents
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD, Adagrad, RMSprop, Adadelta, Adam

X = np.array([[0,0],[0,1],[1,0],[1,1]])
y = np.array([[0],[1],[1],[0]])

def run_model(optimizer,batch_size,name):

    model = Sequential([
        Dense(4,activation='relu',input_shape=(2,)),
        Dense(1,activation='sigmoid')
    ])

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    model.fit(X,y,epochs=500,batch_size=batch_size,verbose=0)

    loss,acc = model.evaluate(X,y,verbose=0)

    print(f"{name} Accuracy:",acc)
    print(model.predict(X))
    print("------------")


# Batch GD
run_model(SGD(learning_rate=0.1),4,"BGD")

# Stochastic GD
run_model(SGD(learning_rate=0.1),1,"SGD")

# Mini Batch GD
run_model(SGD(learning_rate=0.1),2,"Mini Batch GD")

# SGD + Momentum
run_model(SGD(learning_rate=0.1,momentum=0.9),4,"SGD Momentum")

# Nesterov
run_model(SGD(learning_rate=0.1,momentum=0.9,nesterov=True),4,"Nesterov")

# Adagrad
run_model(Adagrad(),4,"Adagrad")

# RMSProp
run_model(RMSprop(),4,"RMSProp")

# Adadelta
run_model(Adadelta(),4,"Adadelta")

# Adam
run_model(Adam(),4,"Adam")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# BGD Accuracy: 0.75
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# [[0.5140732 ]
#  [0.9528863 ]
#  [0.5140732 ]
#  [0.03199661]]
# ------------
# SGD Accuracy: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [[0.03543599]
#  [0.9951942 ]
#  [0.9939482 ]
#  [0.00311056]]
# ------------
# Mini Batch GD Accuracy: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# [[0.03648896]
#  [0.98965156]
#  [0.98981786]
#  [0.03648535]]
# ------------
# SGD Momentum Accuracy: 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [[0.00525598]
#  [0.99894714]
#  [0.9989613 ]
#  [0.00525191]]
# ------------
# ...
